# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /kaggle/working

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.1 MB/s eta 0:00:00
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics --upgrade


from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics 8.3.240 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6582.3/8062.4 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="BX5Dn0yIiAamUr83YZA3")
project = rf.workspace("utd-0dazj").project("utd2-hyo53")
dataset = project.version(5).download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 96.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import torch

from IPython.display import Image, clear_output  # to display images
#from utils.downloads import gdrive_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.8.0+cu126 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15095MB, multi_processor_count=40, uuid=0567aa28-7fef-66c1-af7e-fe0e21a27789, pci_bus_id=0, pci_device_id=4, pci_domain_id=0, L2_cache_size=4MB)

# %%
import glob

# Inisialisasi list kosong
my_list = []

# Loop semua file .txt di folder labels
for filepath in glob.glob('/kaggle/working/utd2-5/test/labels/*.txt'):
    with open(filepath, 'r') as f:
        # Baca semua baris, strip newline, dan tambahkan ke my_list
        my_list.extend([line.strip() for line in f])

# Cek jumlah data
print(f"Total baris yang dikumpulkan: {len(my_list)}")

for i in range(0,len(my_list)):
    my_list[i]=int(my_list[i][0])
len(my_list)

count=0
for i in range(len(my_list)):
  if(my_list[i] not in [0,1,2]):
    count+=1
count
# Out:
# Total baris yang dikumpulkan: 719
# 0

# %%
# %cd /kaggle/working
# !pip install gdown
# !gdown --id 1Agl194CCpdrYvW2GW-reOQqkIYXzfxGj
#https://drive.google.com/file/d/1Agl194CCpdrYvW2GW-reOQqkIYXzfxGj/view?usp=sharing
# Out:
# /kaggle/working
# ...
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Agl194CCpdrYvW2GW-reOQqkIYXzfxGj
# To: /kaggle/working/data_yolov8.yaml
# 100%|██████████████████████████████████████████| 314/314 [00:00<00:00, 1.56MB/s]

# %%
# %cat '
/kaggle/working/data.yaml'
# Out:
#   File "/tmp/ipykernel_24/3748009335.py", line 2
#     kaggle/working/data.yaml'()
#                             ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %cd /kaggle/working

# !yolo task=detect mode=train model=yolov8s.pt \
data=/kaggle/working/utd2-5/data.yaml \
epochs=200 \
imgsz=416 \
batch=160 \
plots=True \
save=True \
device=0,1 \
workers=16 \
project=/kaggle/working

# %%
# !pip install gdown
# !gdown --id 12MBRCO6s8LmJ6HB9qaBKJTjzrzZz9QRO -O best1.pt

# %%
data_yaml = """
train: /kaggle/working/utd2-5/train/images
val: /kaggle/working/utd2-5/valid/images
test: /kaggle/working/utd2-5/test/images

nc: 3
names: ['Bio', 'Rov', 'Trash']

roboflow:
  workspace: utd-0dazj
  project: utd2-hyo53
  version: 5
  license: CC BY 4.0
  url: https://universe.roboflow.com/utd-0dazj/utd2-hyo53/dataset/5
"""

# Menyimpan file data.yaml dengan nama data_yolov11.yaml
with open('/kaggle/working/data_yolov8.yaml', 'w') as file:
    file.write(data_yaml)

print("File data_yolov8.yaml telah disimpan!")

# %%
# !yolo val model=/kaggle/working/best1.pt data=/kaggle/working/data_yolov8.yaml imgsz=416 batch=16

# %%
# %cd /kaggle/working
# !yolo task=detect mode=predict model=/content/drive/MyDrive/!yolov8_ckpt/train2/weights/best.pt  source=/content/utd2-5/test/images data=/content/utd2-5/data.yaml imgsz=416 plots=True save=True plots=True project=/content/drive/MyDrive/!yolov8_ckpt

# %%
# !zip -r /kaggle/working/train5.zip /kaggle/working/train5
